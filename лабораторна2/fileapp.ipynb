# %%
from datetime import datetime
name = "Yevhen"
location = "Humburg"
print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Yevhen start programming at 2026-01-11 03:02:33.361887. Humburg is the best city!
